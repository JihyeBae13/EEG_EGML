% %%
run make_full_table.m
% Out:
% euclidean FTA_Features, Subject_B, m085z000 , run_1
% mean test accuracy 0.606164, std 0.089821
%   Columns 1 through 7
%
%     0.4384    0.3784    0.2432    0.3108    0.3514    0.5676    0.4865
%
%   Columns 8 through 10
%
%     0.3919    0.3784    0.3919
%
% euclidean FTA_Features, Subject_B, z000p085 , run_1
% mean test accuracy 0.656294, std 0.067452
%   Columns 1 through 7
%
%     0.3425    0.3919    0.2703    0.2703    0.3784    0.4865    0.2973
%
%   Columns 8 through 10
%
%     0.3649    0.2838    0.3514
%
% euclidean FTA_Features, Subject_C1, m085z000 , run_1
% mean test accuracy 0.736765, std 0.047671
%   Columns 1 through 7
%
%     0.3088    0.2609    0.2899    0.2174    0.2174    0.2754    0.3188
%
%   Columns 8 through 10
%
%     0.2319    0.1884    0.3235
%
% euclidean FTA_Features, Subject_C1, z000p085 , run_1
% mean test accuracy 0.844608, std 0.042895
%   Columns 1 through 7
%
%     0.0882    0.1739    0.2174    0.2029    0.1304    0.1449    0.1739
%
% ...
